# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
from einops import rearrange
from PIL import Image
from tqdm import tqdm
import json
import time
from pathlib import Path
from sklearn import linear_model
import mediapy as media

# %%
# %ls -lt baselines
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 4E53-844D
#
#  Directory of c:\Users\Owner\Documents\PokemonRedRL
#
#
#  Directory of c:\Users\Owner\Documents\PokemonRedRL\baselines
#
# 08/06/2024  11:55 PM    <DIR>          .
# 07/26/2024  12:04 PM    <DIR>          ..
# 08/06/2024  11:55 PM    <DIR>          __pycache__
# 07/26/2024  11:35 AM                 4 agent_enabled.txt
# 07/26/2024  11:35 AM                53 delete_empty_imgs.txt
# 07/26/2024  11:35 AM    <DIR>          grid_renders
# 07/26/2024  11:35 AM               845 memory_addresses.py
# 07/26/2024  11:35 AM    <DIR>          ray_exp
# 07/26/2024  11:35 AM            24,936 red_gym_env.py
# 07/26/2024  11:35 AM             2,869 render_all_needed_grids.py
# 07/26/2024  11:35 AM                83 render_all_needed_grids.sh
# 07/26/2024  11:35 AM             1,745 requirements.txt
# 07/26/2024  11:35 AM               221 requirements-unfrozen.txt
# 07/26/2024  11:35 AM             2,743 run_baseline_parallel.py
# 07/26/2024  11:35 AM             3,193 run_baseline_parallel_fast.py
# 07/26/2024  11:35 AM             2,387 run_pretrained_interactive.py
# 07/26/2024  11:35 AM             1,233 run_recorded_actions.py
# 07/26/2024  11:35 AM             2,580 saves_to_record.txt
# 08/07/2024  12:40 AM    <DIR>          session_1d8a6082
# 07/26/2024  11:35 AM    <DIR>          session_4da05e87_main_good
# 07/26/2024  12:17 PM    <DIR>          session_614d19f9
# 08/06/2024  11:46 PM    <DIR>          session_ab00ffe8
# 07/26/2024  11:50 AM    <DIR>          session_bd017ed5
# 07/26/2024  11:51 AM    <DIR>          session_f63618a8
# 07/26/2024  11:35 AM             2,230 stream_agent_wrapper.py
# 07/26/2024  11:35 AM             1,451 tensorboard_callback.py
# 07/26/2024  11:35 AM             3,073 tile_vids_to_grid.py
# 07/26/2024  11:35 AM           817,492 Visualizations_over_time.ipynb
#               17 File(s)        867,138 bytes
#               11 Dir(s)  396,544,143,360 bytes free
# File Not Found

# %%
def load_run_data(run_path):
    run_lists = []
    for p in Path(run_path).glob('all_runs_*.json'):
        with open(p, 'r') as f:
            run_lists.append(json.load(f))
    all_runs = [val for tup in zip(*run_lists) for val in tup]
    print(f'runs loaded: {len(all_runs)}')
    return all_runs

# %%
def plot_runs(
    all_runs, use_keys=None, 
    plot_fit=False, plot_line=False, 
    start=0, group_runs=1,
    agg_func=np.mean):
    
    all_runs = all_runs[start:]
    x = np.arange(len(all_runs)//group_runs)
    
    def add_plot(y, name, alpha, size, plot_line, plot_fit):
        plt.scatter(x, y, alpha=alpha, s=size, label=name)
        if plot_line:
            plt.plot(x, y, alpha=alpha, label=name)
        if plot_fit:
            regr = linear_model.LinearRegression()
            # Optimize linear model
            regr.fit(x.reshape(-1, 1), y.reshape(-1, 1))

            # Make predictions using the testing set
            lin_y = regr.predict(x.reshape(-1, 1))
            plt.plot(x, lin_y, linewidth=3)
    
    # convert list of dictionaries to dictionary of lists
    metrics = {m: [run[m] for run in all_runs] for m in all_runs[0].keys()}
    metrics['total'] = [sum([v for _,v in run.items()]) for run in all_runs]
    if group_runs:
        for m, dat in metrics.items():
            metrics[m] = agg_func(np.array(dat).reshape(-1, group_runs), 1)
    available_keys = metrics.keys()
    print(f'available metrics: {list(available_keys)}')
    if use_keys is None:
        use_keys = available_keys
    
    ## TODO subplot for each metric ## 
    NUM_COLORS = len(use_keys)
    cm = plt.get_cmap('Dark2')
    cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
    scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
    fig = plt.figure(figsize = (12, 8))

    ax = fig.add_subplot(111)
    ax.set_prop_cycle(color=[scalarMap.to_rgba(i) for i in range(NUM_COLORS)])

    for i, m in enumerate(use_keys):
        add_plot(
            np.array(metrics[m]), m, 1.0, 3.0, plot_line, plot_fit
        )

    plt.title('Reward over runs PPO')
    plt.legend(bbox_to_anchor=(1.04, 0.5), loc="center left", borderaxespad=0)
    plt.show()

# %%
def get_latest_grid(pth):
    imgs = np.array([np.array(Image.open(p)) for p in Path(pth).glob('curframe*.jpeg')])
    print(f'imgs.shape = {imgs.shape}')
    grid = rearrange(imgs, '(h2 w2) h w c -> (h2 h) (w2 w) c', w2=4)
    return grid

# %%
'''
get_im_func = lambda: get_latest_grid('baselines/session_d34118d3')

with media.VideoWriter('test_grid.mp4', get_im_func().shape[:2]) as wr:
    for i in range(500):
        #wr.add_image(get_im_func())
        #time.sleep(1)
'''
# Out:
# "\nget_im_func = lambda: get_latest_grid('baselines/session_d34118d3')\n\nwith media.VideoWriter('test_grid.mp4', get_im_func().shape[:2]) as wr:\n    for i in range(500):\n        #wr.add_image(get_im_func())\n        #time.sleep(1)\n"

# %%
plt.figure(figsize = (32, 32))
plt.imshow(get_latest_grid('baselines\session_1d8a6082'))
# Out:
# imgs.shape = (16, 144, 160, 3)

# %%
(29556736 - 25952256) / (1024*16*44)
# Out:
# 5.0

# %%
plot_runs(
    load_run_data('baselines\session_1d8a6082'),
    use_keys=None,
    plot_line=False,
    plot_fit=False,
    start=44*0,
    group_runs=44,
    agg_func=np.mean
)
# Out:
# runs loaded: 64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 plot_runs(
#       2     load_run_data('baselines\session_1d8a6082'),
#       3     use_keys=None,
#       4     plot_line=False,
#       5     plot_fit=False,
#       6     start=44*0,
#       7     group_runs=44,
#       8     agg_func=np.mean
#       9 )
#
# Cell In[78], line 2, in plot_runs(data, use_keys, plot_line, plot_fit, start, group_runs, agg_func)
#       1 def plot_runs(data, use_keys=None, plot_line=False, plot_fit=False, start=0, group_runs=None, agg_func=np.mean):
# ----> 2     metrics = data['metrics']
#       3     if group_runs:
#       4         for m, dat in metrics.items():
#
# TypeError: list indices must be integers or slices, not str

# %%
plot_runs(
    load_run_data('baselines/session_1d8a6082'),
    use_keys=None,
    plot_line=False,
    plot_fit=False,
    group_runs=44,
    agg_func=np.mean
)
# Out:
# runs loaded: 64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 plot_runs(
#       2     load_run_data('baselines/session_1d8a6082'),
#       3     use_keys=None,
#       4     plot_line=False,
#       5     plot_fit=False,
#       6     group_runs=44,
#       7     agg_func=np.mean
#       8 )
#
# Cell In[78], line 2, in plot_runs(data, use_keys, plot_line, plot_fit, start, group_runs, agg_func)
#       1 def plot_runs(data, use_keys=None, plot_line=False, plot_fit=False, start=0, group_runs=None, agg_func=np.mean):
# ----> 2     metrics = data['metrics']
#       3     if group_runs:
#       4         for m, dat in metrics.items():
#
# TypeError: list indices must be integers or slices, not str

# %%
plot_runs(
    load_run_data('baselines/session_812437f3_3k_explore'),
    use_keys=None,
    plot_line=False,
    plot_fit=False,
    start=0,
    group_runs=1,
    agg_func=np.mean
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plot_runs(
#       2     load_run_data('baselines/session_812437f3_3k_explore'),
#       3     use_keys=None,
#       4     plot_line=False,
#       5     plot_fit=False,
#       6     start=0,
#       7     group_runs=1,
#       8     agg_func=np.mean
#       9 )
#
# NameError: name 'plot_runs' is not defined

# %%
plot_runs(
    load_run_data('baselines/session_82b536f8_makes_it_to_gym'),
    use_keys=['explore'],
    plot_line=False,
    plot_fit=False,
    start=0,
    group_runs=1,
    agg_func=np.mean
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 plot_runs(
#       2     load_run_data('baselines/session_82b536f8_makes_it_to_gym'),
#       3     use_keys=['explore'],
#       4     plot_line=False,
#       5     plot_fit=False,
#       6     start=0,
#       7     group_runs=1,
#       8     agg_func=np.mean
#       9 )
#
# NameError: name 'plot_runs' is not defined

# %%
plot_runs(
    load_run_data('baselines/session_bad50734'),
    use_keys=None,
    plot_line=False,
    plot_fit=False,
    start=0,
    group_runs=1,
    agg_func=np.mean
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plot_runs(
#       2     load_run_data('baselines/session_bad50734'),
#       3     use_keys=None,
#       4     plot_line=False,
#       5     plot_fit=False,
#       6     start=0,
#       7     group_runs=1,
#       8     agg_func=np.mean
#       9 )
#
# NameError: name 'plot_runs' is not defined

# %% [markdown]
# ## generate moving histograms!

# %%
len(load_run_data('baselines/session_4da05e87_main_full'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 len(load_run_data('baselines/session_4da05e87_main_full'))
#
# Cell In[1], line 3, in load_run_data(run_path)
#       1 def load_run_data(run_path):
#       2     run_lists = []
# ----> 3     for p in Path(run_path).glob('all_runs_*.json'):
#       4         with open(p, 'r') as f:
#       5             run_lists.append(json.load(f))
#
# NameError: name 'Path' is not defined

# %%
def chunks(data, n):
    n = max(1, n)
    return [data[i:i+n] for i in range(0, len(data), n)]

# %%
full_dat = load_run_data('baselines/session_4da05e87_main_full')
for run in full_dat:
    run["total"] = sum(value for value in run.values())
full_dat_chunks = chunks(full_dat, 44)
# Out:
# runs loaded: 26840

# %%
full_dat[0]
# Out:
# {'event': 0,
#  'level': 2,
#  'heal': 0.7431809773652174,
#  'op_lvl': 0.0,
#  'dead': -0.30000000000000004,
#  'badge': 0,
#  'explore': 1.488,
#  'total': 3.931180977365217}

# %%
def histo_plot(axis, stat, dat_chunks, version, compare_count):
    
    test_dat = np.array([run[stat] for run in dat_chunks[version]])
    # the histogram of the data
    n, bins, patches = axis.hist(test_dat, 10, density=False, facecolor="orange", alpha=0.95)
    
    for i in range(compare_count):
        comp_version = max(version - 1 - i, 0)
        compare_dat = np.array([run[stat] for run in dat_chunks[comp_version]])
        n, bins, patches = axis.hist(compare_dat, 10, density=False, facecolor="grey", alpha=0.2*0.25**i)

    axis.set(xlabel=f"{stat}")
    #axis.ylabel()
    # only use this title over all plots
    #axis.title()
    #plt.xlim(40, 160)
    #plt.ylim(0, 0.03)
    #axis.grid(True)
    #plt.show()

# %%
def plot_all(dat_chunks, version, compare_count):
    fig, axs = plt.subplots(2, 4, figsize=(16, 9), dpi=120)
    #plt.subplots_adjust(bottom=0.0, right=0.8, top=0.9)
    fig.suptitle(f"Version {version} Rewards")
    for stat, ax in zip(dat_chunks[0][0].keys(), axs.flatten()):
        histo_plot(ax, stat, dat_chunks, version, compare_count)
    return fig

# %%
plot_all(chunks(full_dat, 44), 10, 5)

# %%
#histo_plot("level", )

# %%
with media.VideoWriter('histograms_over_time.mp4', (1080, 1920)) as wr:
    for i in tqdm(range(610)):
        #with plt.style.context('Solarize_Light2'):
        fig = plot_all(full_dat_chunks, i, 5)

        fig.canvas.draw()
        #plt.show()
        data = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8)
        data = data.reshape(fig.canvas.get_width_height()[::-1] + (3,))
        wr.add_image(data)
        plt.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [219], in <cell line: 1>()
#       1 with media.VideoWriter('histograms_over_time.mp4', (1080, 1920)) as wr:
# ----> 2     for i in tqdm(range(610)):
#       3         #with plt.style.context('Solarize_Light2'):
#       4         fig = plot_all(full_dat_chunks, i, 5)
#       6         fig.canvas.draw()
#
# TypeError: 'module' object is not callable
